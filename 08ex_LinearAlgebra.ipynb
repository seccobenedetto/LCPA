# %%
# general libraries:
import numpy as np
import numpy.random as npr
npr.seed(123) # fix seed for reproducible result
import matplotlib.pyplot as plt
from scipy import linalg as la
import pandas as pd

# %% [markdown]
# ### 1\. PCA on 3D dataset

# %% [markdown]
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normal distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
npr.seed(123) # fix seed for reproducible result
N = 1000      # number of points

# let's build the datasets remembering to normalize the means to 0 to have better statistics (for SVD)
x1 = npr.normal(0,1, 1000)
x2 = x1 + npr.normal(0,3, 1000)
x3 = 2*x1 + x2
x1 -= x1.mean()
x2 -= x2.mean()
x3 -= x3.mean()
df = pd.DataFrame( {'x1':x1,'x2':x2, 'x3':x3} )

# eigendecomposition of covariance matrix:
cov = np.cov(df.T)        # covariance matrix
print(f"Covariance matrix: \n {cov} \n")
l, v = la.eig(cov)        # eigenvalues and eigenvectors
l = np.real_if_close(l)   # let's discard the imaginary part due to calculations
print(f"Eigenvalues of cov matrix: \n {l}")
print(f"Eigenvectors of cov matrix: \n {v} \n")

# let's do it with SVD:   ('t' means transpose)
    # memo: svd of a dataset X give us U,D,Vt where Vt's colums are eigenvectors of Xt*X and D are the squared eigenvalues normalized by n-1
    # and the covariance of the dataset X is exactly cov(X)= (Xt*X)/(n-1)!!!
    # so by doing ls.svd(X) we obtain also the eigendecomposition of the covariance matrix of the dataset X
U, spectrum, Vt = la.svd(df)
l_svd = (spectrum**2)/(N-1)
print(f"Eigenvalues with SVD (and ordered): \n {l_svd}")
v_svd = Vt
print(f"Eigenvectors with SVD (and ordered): \n {v_svd.T}")

print(f"Are the two results compatible with tolerance 0.001? {np.allclose(np.sort(l), np.sort(l_svd), rtol=0.010)} \n")

# the variability explained by each component is the fraction of tha eigenvalue over the total:
tot_avl = l_svd[0]+l_svd[1]+l_svd[2]
print(f"Variability of components:   1 : {l_svd[0]/tot_avl}   2 : {l_svd[1]/tot_avl}   3 : {l_svd[2]/tot_avl}")
# Out:
# Covariance matrix:
#  [[ 1.00257827  0.9125078   2.91766434]
#  [ 0.9125078   9.0907464  10.91576199]
#  [ 2.91766434 10.91576199 16.75109067]]
#
# Eigenvalues of cov matrix:
#  [2.48444042e+01 1.66886524e-16 2.00001118e+00]
# Eigenvectors of cov matrix:
#  [[-0.12126076 -0.81649658  0.56447246]
#  [-0.57007399 -0.40824829 -0.71298596]
#  [-0.81259551  0.40824829  0.41595897]]
#
# Eigenvalues with SVD (and ordered):
#  [2.48444042e+01 2.00001118e+00 1.58620777e-31]
# Eigenvectors with SVD (and ordered):
#  [[ 0.12126076 -0.56447246  0.81649658]
#  [ 0.57007399  0.71298596  0.40824829]
#  [ 0.81259551 -0.41595897 -0.40824829]]
# Are the two results compatible with tolerance 0.001? True
#
# Variability of components:   1 : 0.9254961914750408   2 : 0.07450380852495918   3 : 5.908892962945768e-33

# %% [markdown]
# We can see that the variability over the three components are divided as: 92,5%, 7,5%, around 0%. So to have at least 99% we can take only the first two components and so reducing the dimensionality of our dataset without losing much information.

# %%
# DIMENSIONALITY REDUCTION:

# METODO A: proietto i dati sulle componenti principali che ho individuato
# ora devo proiettare il dataset sulla matrice data dagli autovettori delle componenti principali scelte! (nel nostro caso due)
proj_matrix = v_svd.T[:, 0:2]    # in this way I select the first two columns
new_data = np.dot(df, proj_matrix)
# check that I have a dataset of 1000x2
print( len(new_data) )
print( len(new_data[0]) )

# METODO B: ruoto semplicemente i dati mettendomi nel sistema delle componenti principali, senza ridurre la dimensione (opzione scelta)
proj_matrix2 = v_svd.T           # I make the projection using ALL the eigenvectors matrix
new_data2 = np.dot(df, proj_matrix2)
# check that I have a dataset of 1000x3
print( len(new_data2) )
print( len(new_data2[0]) )
# Out:
# 1000
# 2
# 1000
# 3

# %%
# PLOT:
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))
axs[0,1].set_title('original')
axs[0,0].scatter(x1, x2, alpha=0.3, label='x=x1, y=x2')
axs[0,1].scatter(x1, x3, alpha=0.3, label='x=x1, y=x3')
axs[0,2].scatter(x2, x3, alpha=0.3, label='x=x2, y=x3')
axs[1,1].set_title('PCA')
axs[1,0].scatter(new_data2[:,0], new_data2[:,1], alpha=0.3, label='x=PCA1, y=PCA2')
axs[1,1].scatter(new_data2[:,0], new_data2[:,2], alpha=0.3, label='x=PCA1, y=PCA3')
axs[1,2].scatter(new_data2[:,1], new_data2[:,2], alpha=0.3, label='x=PCA2, y=PCA3')
axs[0,0].legend()
axs[0,1].legend()
axs[0,2].legend()
axs[1,0].legend()
axs[1,1].legend()
axs[1,2].legend()

# %% [markdown]
# NOTE: the only important graph of is the one in the bottom left, which show the two principal components chosen. the next two are on minimal scale (as expected): see the y scale!
#
# In this exercise we successfully used PCA to reduce the dimension of valuable variable from 3 to 2.

# %% [markdown]
# ### 2\. **PCA on a nD dataset**
#
# Start from the dataset you have generated in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
npr.seed(123) # fix seed for reproducible result
N = 1000      # number of points

noise1 = [ np.sum( npr.normal(0, 1/50, N) ) for i in range(N) ]   # list 1000x1
noise2 = [ np.sum( npr.normal(0, 1/50, N) ) for i in range(N) ]   # list 1000x1
noise3 = [ np.sum( npr.normal(0, 1/50, N) ) for i in range(N) ]   # list 1000x1
x1 += noise1
x2 += noise2
x3 += noise3
df_new = pd.DataFrame( {'x1': x1, 'x2': x2, 'x3': x3} ) 

# SVD:
U, S, Vt = la.svd(df_new)
l_svd = S**2/(N-1)
v_svd = Vt.T
print(f"autovalori: \n {l_svd}")
print(f"autovettori: \n {v_svd}")

# PCA:
tot_variab = np.sum(l_svd)
variab = [ l_svd[i]/tot_variab for i in range(3) ]
print(f"PCA: \n {variab}")
# Out:
# autovalori:
#  [48.64283663 27.57149042 25.93234687]
# autovettori:
#  [[-0.04780161  0.87818903  0.47591914]
#  [-0.56281658 -0.41730768  0.71350669]
#  [-0.82519846  0.23374842 -0.51420733]]
# PCA:
#  [0.47620578102884786, 0.26992058927441814, 0.25387362969673394]

# %% [markdown]
# This time there is no clear better choice! So we use the previous named 'method B' for rotating:

# %%
new_dataset = np.dot(df_new, Vt.T)
# check that I have a dataset of 1000x3
print( len(new_dataset) )
print( len(new_dataset[0]) )
# Out:
# 1000
# 3

# %%
# PLOT: (same as before)
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))
axs[0,1].set_title('original')
axs[0,0].scatter(x1, x2, alpha=0.3, label='x=x1, y=x2')
axs[0,1].scatter(x1, x3, alpha=0.3, label='x=x1, y=x3')
axs[0,2].scatter(x2, x3, alpha=0.3, label='x=x2, y=x3')
axs[1,1].set_title('PCA')
axs[1,0].scatter(new_dataset[:,0], new_dataset[:,1], alpha=0.3, label='x=PCA1, y=PCA2')
axs[1,1].scatter(new_dataset[:,0], new_dataset[:,2], alpha=0.3, label='x=PCA1, y=PCA3')
axs[1,2].scatter(new_dataset[:,1], new_dataset[:,2], alpha=0.3, label='x=PCA2, y=PCA3')
axs[0,0].legend()
axs[0,1].legend()
axs[0,2].legend()
axs[1,0].legend()
axs[1,1].legend()
axs[1,2].legend()

# %% [markdown]
# This time all the directions all valuable, and we can't do much with PCA.

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
