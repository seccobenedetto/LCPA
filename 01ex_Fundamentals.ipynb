# %% [markdown]
# # Esercizi-01

# %% [markdown]
# ### 0\.
# Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.

# %%
# creazione file esterno
fin = open('function.py', 'w')
fin.write('def swap(a,b): return b, a')
fin.close()

# %%
import function as func
print( func.swap(3,4) )
# Out:
# (4, 3)

# %% [markdown]
# ### 1\.
# Write the following as a list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print (ans) 

# 2
ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
print (list(ans))
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %%
# 1
ans = [ (i,j)for i in range(3) for j in range(4)]
print(ans)

# 2
print([x*x for x in range(5) if x%2 == 0])
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %% [markdown]
# ### 2\.
# Convert the following function into a pure function with no global variables or side effects

# %%
x = 5
def f(alist):
    for i in range(x):
        alist.append(i)
    return alist

alist = [1,2,3]
ans = f(alist)
print (ans)
print (alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3, 0, 1, 2, 3, 4]

# %%
# solution:
x = 5
def f(alist):
    copia = alist.copy()
    for i in range(x):
        copia.append(i)
    return copia

alist = [1,2,3]
ans = f(alist)
print ('nuovo: ' , ans)
print ('originale: ', alist) # alist has been changed!

# alternativa: crea una nuova lista copiando gli elementi uno per uno
# alternativa: usa una tuple e concatena una list
# Out:
# nuovo:  [1, 2, 3, 0, 1, 2, 3, 4]
# originale:  [1, 2, 3]

# %% [markdown]
# ### 3\.
# Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
def hello(func):
    def wrapper(x): 
        print("Hello!")
        return func(x)
    return wrapper

@hello
def square(x): return x**2

print( square(5) )
# Out:
# Hello!
# 25

# %% [markdown]
# ### 4\.
# Write the factorial function so that it a) does and b) does not use recursion.

# %%
# WITH recursion:
def fact1(n):
    if n == 0:
        result = 1
    else: result = n*fact1(n-1)
    return result
print ([fact1(i) for i in range(10)])

# WITHOUT recursion:
def fact2(n):
    if n == 0:
        result = 1
    else: 
        result = 1
        for i in range(1, n+1):
            result *= i
    return result
print ([fact2(i) for i in range(10)])
# Out:
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880]
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880]

# %% [markdown]
# ### 5\.
# Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
# radii = [1,2,3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.

# %%
densities = {"Al" : [0.5, 1, 2], "Fe" : [3, 4, 5], "Pb" : [15, 20, 30]}
radii = [1, 2, 3]

from numpy import pi as pi
dens = list( densities.values() )
# memo: circonference=2*pi*r, circle=pi*r**2, sphere=4/3*pi*r**3
volumes = [lambda r,i=i,j=j: i*pi*(r**j) for (i,j) in zip([2,1,4/3], [1,2,3]) ]    # i sono i coefficienti delle formule, j le potenze
# calcoliamo masse come prodotto densità per volume:
weights = [volumes[i](r)*dens[k][l] for r in radii for i in [0,1,2] for k in [0,1,2] for l in [0,1,2] ]
# stampiamo in modo chiaro i risultati:
i=-1
for key in densities:
    i += 1
    for dens_index in range(3):
        for r in radii:
            for k in range(3):
                print(f"The mass of {key} with density {densities[key][dens_index]} and radius {r} in dimension {k+1} is {volumes[k](r)*dens[i][dens_index]}")
# Out:
# The mass of Al with density 0.5 and radius 1 in dimension 1 is 3.141592653589793
# The mass of Al with density 0.5 and radius 1 in dimension 2 is 1.5707963267948966
# The mass of Al with density 0.5 and radius 1 in dimension 3 is 2.0943951023931953
# The mass of Al with density 0.5 and radius 2 in dimension 1 is 6.283185307179586
# The mass of Al with density 0.5 and radius 2 in dimension 2 is 6.283185307179586
# The mass of Al with density 0.5 and radius 2 in dimension 3 is 16.755160819145562
# The mass of Al with density 0.5 and radius 3 in dimension 1 is 9.42477796076938
# The mass of Al with density 0.5 and radius 3 in dimension 2 is 14.137166941154069
# The mass of Al with density 0.5 and radius 3 in dimension 3 is 56.54866776461627
# The mass of Al with density 1 and radius 1 in dimension 1 is 6.283185307179586
# The mass of Al with density 1 and radius 1 in dimension 2 is 3.141592653589793
# The mass of Al with density 1 and radius 1 in dimension 3 is 4.1887902047863905
# The mass of Al with density 1 and radius 2 in dimension 1 is 12.566370614359172
# The mass of Al with density 1 and radius 2 in dimension 2 is 12.566370614359172
# The mass of Al with density 1 and radius 2 in dimension 3 is 33.510321638291124
# The mass of Al with density 1 and radius 3 in dimension 1 is 18.84955592153876
# The mass of Al with density 1 and radius 3 in dimension 2 is 28.274333882308138
# The mass of Al with density 1 and radius 3 in dimension 3 is 113.09733552923254
# The mass of Al with density 2 and radius 1 in dimension 1 is 12.566370614359172
# The mass of Al with density 2 and radius 1 in dimension 2 is 6.283185307179586
# The mass of Al with density 2 and radius 1 in dimension 3 is 8.377580409572781
# The mass of Al with density 2 and radius 2 in dimension 1 is 25.132741228718345
# The mass of Al with density 2 and radius 2 in dimension 2 is 25.132741228718345
# The mass of Al with density 2 and radius 2 in dimension 3 is 67.02064327658225
# The mass of Al with density 2 and radius 3 in dimension 1 is 37.69911184307752
# The mass of Al with density 2 and radius 3 in dimension 2 is 56.548667764616276
# The mass of Al with density 2 and radius 3 in dimension 3 is 226.19467105846508
# The mass of Fe with density 3 and radius 1 in dimension 1 is 18.84955592153876
# The mass of Fe with density 3 and radius 1 in dimension 2 is 9.42477796076938
# The mass of Fe with density 3 and radius 1 in dimension 3 is 12.566370614359172
# The mass of Fe with density 3 and radius 2 in dimension 1 is 37.69911184307752
# The mass of Fe with density 3 and radius 2 in dimension 2 is 37.69911184307752
# The mass of Fe with density 3 and radius 2 in dimension 3 is 100.53096491487338
# The mass of Fe with density 3 and radius 3 in dimension 1 is 56.548667764616276
# The mass of Fe with density 3 and radius 3 in dimension 2 is 84.82300164692441
# The mass of Fe with density 3 and radius 3 in dimension 3 is 339.29200658769764
# The mass of Fe with density 4 and radius 1 in dimension 1 is 25.132741228718345
# The mass of Fe with density 4 and radius 1 in dimension 2 is 12.566370614359172
# The mass of Fe with density 4 and radius 1 in dimension 3 is 16.755160819145562
# The mass of Fe with density 4 and radius 2 in dimension 1 is 50.26548245743669
# The mass of Fe with density 4 and radius 2 in dimension 2 is 50.26548245743669
# The mass of Fe with density 4 and radius 2 in dimension 3 is 134.0412865531645
# The mass of Fe with density 4 and radius 3 in dimension 1 is 75.39822368615503
# The mass of Fe with density 4 and radius 3 in dimension 2 is 113.09733552923255
# The mass of Fe with density 4 and radius 3 in dimension 3 is 452.38934211693015
# The mass of Fe with density 5 and radius 1 in dimension 1 is 31.41592653589793
# The mass of Fe with density 5 and radius 1 in dimension 2 is 15.707963267948966
# The mass of Fe with density 5 and radius 1 in dimension 3 is 20.94395102393195
# The mass of Fe with density 5 and radius 2 in dimension 1 is 62.83185307179586
# The mass of Fe with density 5 and radius 2 in dimension 2 is 62.83185307179586
# The mass of Fe with density 5 and radius 2 in dimension 3 is 167.5516081914556
# The mass of Fe with density 5 and radius 3 in dimension 1 is 94.24777960769379
# The mass of Fe with density 5 and radius 3 in dimension 2 is 141.3716694115407
# The mass of Fe with density 5 and radius 3 in dimension 3 is 565.4866776461627
# The mass of Pb with density 15 and radius 1 in dimension 1 is 94.24777960769379
# The mass of Pb with density 15 and radius 1 in dimension 2 is 47.12388980384689
# The mass of Pb with density 15 and radius 1 in dimension 3 is 62.831853071795855
# The mass of Pb with density 15 and radius 2 in dimension 1 is 188.49555921538757
# The mass of Pb with density 15 and radius 2 in dimension 2 is 188.49555921538757
# The mass of Pb with density 15 and radius 2 in dimension 3 is 502.65482457436684
# The mass of Pb with density 15 and radius 3 in dimension 1 is 282.7433388230814
# The mass of Pb with density 15 and radius 3 in dimension 2 is 424.11500823462205
# The mass of Pb with density 15 and radius 3 in dimension 3 is 1696.460032938488
# The mass of Pb with density 20 and radius 1 in dimension 1 is 125.66370614359172
# The mass of Pb with density 20 and radius 1 in dimension 2 is 62.83185307179586
# The mass of Pb with density 20 and radius 1 in dimension 3 is 83.7758040957278
# The mass of Pb with density 20 and radius 2 in dimension 1 is 251.32741228718345
# The mass of Pb with density 20 and radius 2 in dimension 2 is 251.32741228718345
# The mass of Pb with density 20 and radius 2 in dimension 3 is 670.2064327658225
# The mass of Pb with density 20 and radius 3 in dimension 1 is 376.99111843077515
# The mass of Pb with density 20 and radius 3 in dimension 2 is 565.4866776461628
# The mass of Pb with density 20 and radius 3 in dimension 3 is 2261.9467105846506
# The mass of Pb with density 30 and radius 1 in dimension 1 is 188.49555921538757
# The mass of Pb with density 30 and radius 1 in dimension 2 is 94.24777960769379
# The mass of Pb with density 30 and radius 1 in dimension 3 is 125.66370614359171
# The mass of Pb with density 30 and radius 2 in dimension 1 is 376.99111843077515
# The mass of Pb with density 30 and radius 2 in dimension 2 is 376.99111843077515
# The mass of Pb with density 30 and radius 2 in dimension 3 is 1005.3096491487337
# The mass of Pb with density 30 and radius 3 in dimension 1 is 565.4866776461628
# The mass of Pb with density 30 and radius 3 in dimension 2 is 848.2300164692441
# The mass of Pb with density 30 and radius 3 in dimension 3 is 3392.920065876976

# %% [markdown]
# ### 6\.
# Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
# class Dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```

# %% [markdown]
# Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `

# %%
# Parent class
class Dog:
    # Class attribute
    species = 'mammal'
    # Initializer / Instance attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.is_hungry = True
    # instance method
    def description(self):
        return f"{self.name} is {self.age} years old"
    # instance method
    def speak(self, sound):
        return f"{self.name} says {sound}"
    def eat(self): self.is_hungry = False

# Child class (inherits from Dog class)
class RussellTerrier(Dog):
    def run(self, speed):
        return f"{self.name} runs {speed}"

# Child class (inherits from Dog class)
class Bulldog(Dog):
    def run(self, speed):
        return f"{self.name} runs {speed}"

# let's write a function that checks if the dogs are hungry
def dogs_hungry(mydogs):
    if my_dogs[0].is_hungry==True and my_dogs[1].is_hungry==True and my_dogs[2].is_hungry==True : print("My dogs are hungry.")
    elif my_dogs[0].is_hungry==False and my_dogs[1].is_hungry==False and my_dogs[2].is_hungry==False : print("My dogs are hungry.")
    else: print( "Some of my dogs are hungry, others aren't" )

# let's define my dogs:
my_dogs = list( [Dog("Tom", 6), Dog("Fletcher", 7), Dog("Larry", 9)] )

# output
print(f"I have {len(my_dogs)} dogs.")
for dog in my_dogs: print(f"{dog.name} is {dog.age}")
print(f"And they are all {my_dogs[0].species}s, of course.")
dogs_hungry(my_dogs)
# Out:
# I have 3 dogs.
# Tom is 6
# Fletcher is 7
# Larry is 9
# And they are all mammals, of course.
# My dogs are hungry.
